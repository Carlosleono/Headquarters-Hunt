# %%
import pandas as pd
import geopandas as gpd
from keplergl import KeplerGl

# %%
bh = pd.read_csv('../data/BeverlyHillsCompleteData.csv')

# %%
bh.sample(5)
# Out:
#     Unnamed: 0                                   _id  \
# 12          12  {'$oid': '61927efa6b0640e76d094fc6'}
# 38          38  {'$oid': '61927efa6b0640e76d094fc1'}
# 33          33  {'$oid': '61927efa6b0640e76d094f8e'}
# 69          69  {'$oid': '61927efa6b0640e76d094fcc'}
# 88          88  {'$oid': '61927efa6b0640e76d094f9c'}
#
#                                                nombre    latitud    longitud  \
# 12                   Grand Havana Room - Private Club  34.069265 -118.399709
# 38                        Hawthorne Elementary School  34.078247 -118.403867
# 33                                       Docler Media  34.065125 -118.412700
# 69  The Low Key Cutty In The Mix Spot II - Electri...  34.054085 -118.412430
# 88                                Christian Louboutin  34.082363 -118.385509
#
#              category  distance  \
# 12           Wine Bar  0.540981
# 38  Elementary School  0.960589
# 33       Tech Startup  0.833200
# 69                Bar  1.850485
# ...

# %%
gdf = gpd.GeoDataFrame(bh, geometry=gpd.points_from_xy(bh.longitud, bh.latitud))

# %%
gdf
# Out:
#     Unnamed: 0                                   _id  \
# 0            0  {'$oid': '61927efa6b0640e76d094f85'}
# 1            1  {'$oid': '61927efa6b0640e76d094f8b'}
# 2            2  {'$oid': '61927efa6b0640e76d094fac'}
# 3            3  {'$oid': '61927efa6b0640e76d094fc2'}
# 4            4  {'$oid': '61927efa6b0640e76d094fe0'}
# ..         ...                                   ...
# 94          94  {'$oid': '61927efa6b0640e76d094fae'}
# 95          95  {'$oid': '61927efa6b0640e76d094f93'}
# 96          96  {'$oid': '61927efa6b0640e76d094f88'}
# 97          97  {'$oid': '61927efa6b0640e76d094f95'}
# 98          98  {'$oid': '61927efa6b0640e76d094faf'}
#
#                                   nombre    latitud    longitud  \
# 0                       SGN Headquarters  34.069603 -118.405702
# 1                Proactive SEO Solutions  34.069263 -118.406696
# 2                          Palter DeLiso  34.068161 -118.404780
# 3                 Buena Vista Cigar Club  34.068354 -118.407765
# ...

# %%
map_1= KeplerGl(height=700, weight = 500, data={'BeverlyHills': gdf})
# Out:
# User Guide: https://docs.kepler.gl/docs/keplergl-jupyter

# %%
map_1
# Out:
# KeplerGl(data={'BeverlyHills':     Unnamed: 0                                   _id  \
# 0            0  {'$oid'…
